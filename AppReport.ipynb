# %%
import pandas as pd
import dryscrape
s= dryscrape.Session()
s.visit("http://localhost:8888/view/Desktop/ML/AppReport.html")
df=pd.read_html(s.body())[5]
df.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-a19401bd91cc> in <module>
#       1 import pandas as pd
# ----> 2 import dryscrape
#       3 s= dryscrape.Session()
#       4 s.visit("http://localhost:8888/view/Desktop/ML/AppReport.html")
#       5 df=pd.read_html(s.body())[5]
#
# ModuleNotFoundError: No module named 'dryscrape'

# %%
pip install BeautifulSoup4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install lxml
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install html5lib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from bs4 import BeautifulSoup
import pandas as pd
pd_df=pd.read_html('C:/Users/su.khan/Desktop/ML/AppReport.html', flavor ='bs4')
pd_df[0]
# Out:
#              0                                              1            2   \
# 0           NaN                                            NaN          NaN
# 1       App Acr                                       App Name  SLA Acronym
# 2         611VA                                   611 View App        611VA
# 3       700TPMF  700 Terminating Point Master File for NPA 700      700TPMF
# 4    800MECH-SU                 800 Mech Su-System Maintenance   800MECH-SU
# ..          ...                                            ...          ...
# 680    WIRELSNM                                  Wireless - NM          NaN
# 681         WMP                    Workforce Management Portal          NaN
# 682        WOAP                 Work Order Appointment Portlet          NaN
# 683         WOM                          Work Order Management          WOM
# 684        WPST             Wholesale Provisioning Status Tool         WPST
#
# ...
