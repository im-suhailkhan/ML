# %%
# %matplotlib inline
import numpy as np
import pandas as pd

data = pd.read_csv (r'C:\Users\su.khan\Desktop\ML\System failure\testout51.csv')

# %%
data.head()
# Out:
#   CPU 1 YBLPVDAKDLWAPP1  User%_CPU1  Sys%_CPU1  Wait%_CPU1  Idle%_CPU1  \
# 0   2019-01-05 00:00:02         3.4        2.5         0.0        94.1
# 1   2019-01-05 00:10:02         6.3        6.8         0.0        87.0
# 2   2019-01-05 00:20:02         2.7        3.5         0.0        93.8
# 3   2019-01-05 00:30:02         2.1        3.0         0.0        95.0
# 4   2019-01-05 00:40:02         2.9        3.5         0.0        93.6
#
#    User%_CPU2  Sys%_CPU2  Wait%_CPU2  Idle%_CPU2  User%_CPU3  ...  \
# 0         4.2        3.4         2.5        89.9         9.2  ...
# 1         4.6        3.9         0.0        91.5         3.1  ...
# 2         2.0        2.7         0.0        95.3         1.0  ...
# 3         1.6        2.6         0.0        95.8         0.9  ...
# 4         1.9        2.9         0.0        95.2         1.3  ...
#
#    sdc_diskbsize  dm-0_diskbsize  dm-1_diskbsize  dm-2_diskbsize  \
# 0           14.0            10.8             4.0             4.0
# ...

# %%
sum_column = data["User%_CPU1"] + data["Sys%_CPU1"]+data["Wait%_CPU1"]
data["CPU1 utilization"] = np.log10(sum_column)

# %%
data.head()
# Out:
#   CPU 1 YBLPVDAKDLWAPP1  User%_CPU1  Sys%_CPU1  Wait%_CPU1  Idle%_CPU1  \
# 0   2019-01-05 00:00:02         3.4        2.5         0.0        94.1
# 1   2019-01-05 00:10:02         6.3        6.8         0.0        87.0
# 2   2019-01-05 00:20:02         2.7        3.5         0.0        93.8
# 3   2019-01-05 00:30:02         2.1        3.0         0.0        95.0
# 4   2019-01-05 00:40:02         2.9        3.5         0.0        93.6
#
#    User%_CPU2  Sys%_CPU2  Wait%_CPU2  Idle%_CPU2  User%_CPU3  ...  \
# 0         4.2        3.4         2.5        89.9         9.2  ...
# 1         4.6        3.9         0.0        91.5         3.1  ...
# 2         2.0        2.7         0.0        95.3         1.0  ...
# 3         1.6        2.6         0.0        95.8         0.9  ...
# 4         1.9        2.9         0.0        95.2         1.3  ...
#
#    dm-0_diskbsize  dm-1_diskbsize  dm-2_diskbsize  dm-3_diskbsize  \
# 0            10.8             4.0             4.0             4.0
# ...

# %%
sum_column = data["User%_CPU2"] + data["Sys%_CPU2"]+data["Wait%_CPU2"]
data["CPU2 utilization"] = np.log10(sum_column)
sum_column = data["User%_CPU3"] + data["Sys%_CPU3"]+data["Wait%_CPU3"]
data["CPU3 utilization"] = np.log10(sum_column)

# %%
data.head()
# Out:
#   CPU 1 YBLPVDAKDLWAPP1  User%_CPU1  Sys%_CPU1  Wait%_CPU1  Idle%_CPU1  \
# 0   2019-01-05 00:00:02         3.4        2.5         0.0        94.1
# 1   2019-01-05 00:10:02         6.3        6.8         0.0        87.0
# 2   2019-01-05 00:20:02         2.7        3.5         0.0        93.8
# 3   2019-01-05 00:30:02         2.1        3.0         0.0        95.0
# 4   2019-01-05 00:40:02         2.9        3.5         0.0        93.6
#
#    User%_CPU2  Sys%_CPU2  Wait%_CPU2  Idle%_CPU2  User%_CPU3  ...  \
# 0         4.2        3.4         2.5        89.9         9.2  ...
# 1         4.6        3.9         0.0        91.5         3.1  ...
# 2         2.0        2.7         0.0        95.3         1.0  ...
# 3         1.6        2.6         0.0        95.8         0.9  ...
# 4         1.9        2.9         0.0        95.2         1.3  ...
#
#    dm-2_diskbsize  dm-3_diskbsize  dm-4_diskbsize  dm-5_diskbsize  \
# 0             4.0             4.0             4.0             4.0
# ...

# %%
sum_column = data["User%_CPU4"] + data["Sys%_CPU4"]+data["Wait%_CPU4"]
data["CPU4 utilization"] = np.log10(sum_column)
sum_column = data["User%_CPU5"] + data["Sys%_CPU5"]+data["Wait%_CPU5"]
data["CPU5 utilization"] = np.log10(sum_column)
sum_column = data["User%_CPU6"] + data["Sys%_CPU6"]+data["Wait%_CPU6"]
data["CPU6 utilization"] = np.log10(sum_column)
sum_column = data["User%_CPU7"] + data["Sys%_CPU7"]+data["Wait%_CPU7"]
data["CPU7 utilization"] = np.log10(sum_column)
sum_column = data["User%_CPU8"] + data["Sys%_CPU8"]+data["Wait%_CPU8"]
data["CPU8 utilization"] = np.log10(sum_column)
sum_column = data["User%_CPU9"] + data["Sys%_CPU9"]+data["Wait%_CPU9"]
data["CPU9 utilization"] = np.log10(sum_column)
sum_column = data["User%_CPU10"] + data["Sys%_CPU10"]+data["Wait%_CPU10"]
data["CPU10 utilization"] = np.log10(sum_column)
sum_column = data["User%_CPU11"] + data["Sys%_CPU11"]+data["Wait%_CPU11"]
data["CPU11 utilization"] = np.log10(sum_column)
sum_column = data["User%_CPU12"] + data["Sys%_CPU12"]+data["Wait%_CPU12"]
data["CPU12 utilization"] = np.log10(sum_column)
sum_column = data["User%_CPU13"] + data["Sys%_CPU13"]+data["Wait%_CPU13"]
data["CPU13 utilization"] = np.log10(sum_column)
sum_column = data["User%_CPU14"] + data["Sys%_CPU14"]+data["Wait%_CPU14"]
data["CPU14 utilization"] = np.log10(sum_column)
sum_column = data["User%_CPU15"] + data["Sys%_CPU15"]+data["Wait%_CPU15"]
data["CPU15 utilization"] = np.log10(sum_column)
sum_column = data["User%_CPU16"] + data["Sys%_CPU16"]+data["Wait%_CPU16"]
data["CPU16 utilization"] = np.log10(sum_column)
sum_column = data["User%_CPU17"] + data["Sys%_CPU17"]+data["Wait%_CPU17"]
data["CPU17 utilization"] = np.log10(sum_column)

# %%
data.head()
# Out:
#   CPU 1 YBLPVDAKDLWAPP1  User%_CPU1  Sys%_CPU1  Wait%_CPU1  Idle%_CPU1  \
# 0   2019-01-05 00:00:02         3.4        2.5         0.0        94.1
# 1   2019-01-05 00:10:02         6.3        6.8         0.0        87.0
# 2   2019-01-05 00:20:02         2.7        3.5         0.0        93.8
# 3   2019-01-05 00:30:02         2.1        3.0         0.0        95.0
# 4   2019-01-05 00:40:02         2.9        3.5         0.0        93.6
#
#    User%_CPU2  Sys%_CPU2  Wait%_CPU2  Idle%_CPU2  User%_CPU3  ...  \
# 0         4.2        3.4         2.5        89.9         9.2  ...
# 1         4.6        3.9         0.0        91.5         3.1  ...
# 2         2.0        2.7         0.0        95.3         1.0  ...
# 3         1.6        2.6         0.0        95.8         0.9  ...
# 4         1.9        2.9         0.0        95.2         1.3  ...
#
#    CPU8 utilization  CPU9 utilization  CPU10 utilization  CPU11 utilization  \
# ...
